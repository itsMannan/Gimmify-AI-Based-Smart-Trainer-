# %% [markdown]
# # 02 — Feature Exploration
#
# Phase 3 scaffold. Lag windows live in `configs/development.yaml`.

# %%
from src.config import load_yaml_config
print(load_yaml_config("development")["features"])
