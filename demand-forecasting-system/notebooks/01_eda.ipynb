# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Phase 1 scaffold. Full EDA lands with the data pipeline (Phase 2).

# %%
from src.config import get_settings, load_yaml_config
settings = get_settings()
print(settings.app_name, settings.environment)
print(load_yaml_config(settings.environment)["app"])
